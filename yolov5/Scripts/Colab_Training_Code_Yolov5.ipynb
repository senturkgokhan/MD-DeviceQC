# %%
# !pip install -q kaggle
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 22.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 78.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="U***")
project = rf.workspace("a-ip3ih").project("quailty_control")
version = project.version(3)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Quailty_Control-3 in yolov5pytorch:: 100%|██████████| 8129/8129 [00:01<00:00, 4829.10it/s]

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17968, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 17968 (delta 95), reused 51 (delta 51), pack-reused 17849 (from 3)
# Receiving objects: 100% (17968/17968), 17.10 MiB | 14.88 MiB/s, done.
# Resolving deltas: 100% (12226/12226), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 14.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
yaml_path = "/content/Quailty_Control-3/data.yaml"

with open(yaml_path, "r") as f:
    print(f.read())
# Out:
# train: /content/Quailty_Control-3/train/images
# val: /content/Quailty_Control-3/valid/images
# test: /content/Quailty_Control-3/test/images
#
# nc: 10
#
# names:
#   - DM100
#   - Ethernet
#   - ID-Switch
#   - Klemens-Group
#   - Led-Group
#   - Quality-Control
#   - SD-Card
#   - Warranty
#   - XIO110
#   - usb-b

# %%
yaml_path = "/content/Quailty_Control-3/data.yaml"

with open(yaml_path, "w") as f:
    f.write("""
train: /content/Quailty_Control-3/train/images
val: /content/Quailty_Control-3/valid/images
test: /content/Quailty_Control-3/test/images

nc: 10

names:
  - DM100
  - Ethernet
  - ID-Switch
  - Klemens-Group
  - Led-Group
  - Quality-Control
  - SD-Card
  - Warranty
  - XIO110
  - usb-b
""")

# %%
# !python train.py \
  --img 832 \
  --batch 8 \
  --epochs 150 \
  --data /content/Quailty_Control-3/data.yaml \
  --weights yolov5s.pt \
  --name quality_control_yolov5s_img832 \
  --patience 30 \
  --workers 2
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   with torch.cuda.amp.autocast(amp):
#     144/149       3.8G    0.01412    0.01169   0.001397         33        832:  46% 207/447 [01:11<01:11,  3.33it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     144/149       3.8G    0.01412    0.01168   0.001395         44        832:  47% 208/447 [01:12<01:26,  2.76it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#     144/149       3.8G    0.01411    0.01166    0.00139         25        832:  47% 209/447 [01:12<01:15,  3.16it/s]/content/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
from google.colab import files
files.download("/content/yolov5/runs/train/quality_control_yolov5s_img832/weights/best.pt")

# %%
# !zip -r yolo_results.zip /content/yolov5/runs/train/quality_control_yolov5s_img832
# Out:
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/ (stored 0%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/val_batch1_pred.jpg (deflated 11%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/weights/best.pt (deflated 10%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/weights/last.pt (deflated 10%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/train_batch2.jpg (deflated 7%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/R_curve.png (deflated 11%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/val_batch2_pred.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/val_batch2_labels.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/quality_control_yolov5s_img832/P_curve.png (deflated 12%)
# ...

# %%
from google.colab import files
files.download("yolo_results.zip")
